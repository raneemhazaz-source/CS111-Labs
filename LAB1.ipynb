# %% [markdown]
# <a href="https://colab.research.google.com/github/raneemhazaz-source/CS111-Labs/blob/master/LAB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=5
type(x)
# Out:
# int

# %%
x = "this is text"
type(x)
# Out:
# str

# %%
name = "phython basics"
print(name.title())
print(name.upper())
print(name.lower())
# Out:
# Phython Basics
# PHYTHON BASICS
# phython basics

# %%
fname="raneem"
lname="hazazi"
fullname=f"{fname}  {lname}"
print(fullname,"start with",fullname[0])
print(fullname.title())
print(len(fullname))
print(fullname.isalpha())
print(fullname.index("h"))
print(fullname.index("r"))
# Out:
# raneem  hazazi start with r
# Raneem  Hazazi
# 14
# False
# 8
# 0

# %%
x,y,z = 5,15,25
print("x=",x,"y=",y,"z=",z)
# Out:
# x= 5 y= 15 z= 25

# %%
PI= 3.14
print(PI)
# Out:
# 3.14

# %%
input("enter your age\n:")
name = input("enteryour name\n")
print(name.upper())
print(f"hello {name}".title())
# Out:
# enter your age
# :19
# enteryour name
# raneem
# RANEEM
# Hello Raneem

# %%
heigth =int (input("how tall are you, in inches?"))
print("your tall is :".title() ,heigth)
# Out:
# how tall are you, in inches?166
# Your Tall Is : 166

# %%
print((1+3)*4)
print(5*9)
print(120%7)#باقي القسمة
print(15//12)
print(int(120/6))
# Out:
# 16
# 45
# 1
# 1
# 20

# %%
a=20
b=13
print(a>b)
print(a==b)
print(a!=b)
print(9!= 6 and 3> 2)
print(9== 2 or 3> 2)
print(not 3> 2)
# Out:
# True
# False
# True
# True
# True
# False

# %%
x=5
if x>4:
  print("x is greater4".title())
# Out:
# X Is Greater4

# %%
num = int(input("\n enter number, and ill tell you if its even pr odd:"))
if num%2 ==0:
  print("even")
else:
  print("odd")
# Out:
#  enter number, and ill tell you if its even pr odd:0
# even

# %%
lentgh=int(input("enter number of inches:"))
feet =lentgh//12
inches=lentgh%12
print(f"{lentgh} in inches equals {feet} feet and {inches} inches")
# Out:
# enter number of inches:185
# 185 in inches equals 15 feet and 5 inches
